# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# Out:
# ...
#   Using cached matplotlib-3.10.6-cp313-cp313-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached kiwisolver-1.4.9-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 3.6 MB/s eta 0:00:03
#    ------ --------------------------------- 1.3/8.1 MB 3.3 MB/s eta 0:00:03
#    --------- ------------------------------ 1.8/8.1 MB 3.4 MB/s eta 0:00:02
#    ------------ --------------------------- 2.6/8.1 MB 3.3 MB/s eta 0:00:02
#    ------------------ --------------------- 3.7/8.1 MB 3.6 MB/s eta 0:00:02
#    --------------------- ------------------ 4.5/8.1 MB 3.8 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.1 MB 3.9 MB/s eta 0:00:01
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt #for data visualization
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\HP\Documents\Diwali Sales Analysis - Python\Diwali Sales Data.csv', encoding = 'unicode_escape')
#to avoid encoding error use, 'unicode escape'

# %%
df.head() # See the first 5 rows
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info() # Get a summary of the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.shape #Check the shape (rows, columns)
# Out:
# (11251, 15)

# %%
df.columns # View column names
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
df.drop(['Status', 'unnamed1'], axis=1, inplace = True, errors='ignore')#drop those columns only if they exist

# %%
print (df.columns.tolist())
# Out:
# ['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age', 'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount']

# %%
pd.isnull(df)#will give values in true and false
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
pd.isnull(df).sum()#summary of missing values per column
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.shape #before using drop
# Out:
# (11251, 13)

# %%
df.dropna(inplace = True)

# %%
df.shape #after using drop
# Out:
# (11239, 13)

# %%
pd.isnull(df).sum()#null values are removed
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
#change data type
df['Amount'] = df['Amount'].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int64')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#renamed column Occupation to Profession
df.rename (columns={'Occupation':'Profession'}, inplace=True)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#returns description of data in dataframe (count, mean, min, max)
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
#use describe for specific columns
df[['Age', 'Orders', 'Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# # **Exlanatory Data Analysis**

# %% [markdown]
# # **Gender**

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Profession', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
# Create the count plot
ax = sns.countplot(x='Gender', data=df)

# Define custom colors (one per bar)
colors = ['skyblue', 'lightgreen']  

# Apply the colors to each bar
for bar, color in zip(ax.patches, colors): 
    bar.set_facecolor(color)
    
# Label the bars
for bars in ax.containers:
    ax.bar_label(bars)
#Title 
plt.title('Total Sales by Gender')
plt.show()

# %%
# Grouping and summing
Sales_gen = df.groupby('Gender', as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

# Plot the barplot and get the Axes object
ax = sns.barplot(x='Gender', y='Amount', data=Sales_gen)

# Define custom colors (one per bar)
colors = ['skyblue', 'pink']  

# Apply the colors to each bar in the Axes object
for bar, color in zip(ax.patches, colors):
    bar.set_facecolor(color)

# Add values on top of each bar
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 10,  # slight padding above the bar
            f'{int(height)}', ha='center', va='bottom', fontsize=14)
# Add title
ax.set_title('Total Sales by Gender')
plt.show()

# %% [markdown]
# #### From above Graphs we can see that most of the buyers are female and the purchasing of females is greater than men

# %% [markdown]
# ## Age Group

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Profession', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
# Create the countplot for AgeGroup
ax = sns.countplot(x='Age Group', data=df)

# Define custom colors — one per age group
colors = ['skyblue', 'lightgreen', 'salmon', 'purple', 'orange']  # length should match unique age groups

# Apply the colors to each bar
for bar, color in zip(ax.patches, colors):
    bar.set_facecolor(color)

# Add values on top of each bar
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 10,  # slight padding above the bar
            f'{int(height)}', ha='center', va='bottom', fontsize=14)

plt.title('Age Group Distribution')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.show()

# %%
# Group and sum Amount by AgeGroup
Sales_age = df.groupby('Age Group', as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

# Plot barplot and get Axes
ax = sns.barplot(x='Age Group', y='Amount', data=Sales_age)

# Define colors — make sure to match number of age groups
colors = ['skyblue', 'lightgreen', 'salmon', 'purple', 'orange']

# Apply colors to bars
for bar, color in zip(ax.patches, colors):
    bar.set_facecolor(color)

# Add values on top of each bar
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 10,  # slight padding above the bar
            f'{int(height)}', ha='center', va='bottom', fontsize=14)    

# Add title and labels
ax.set_title('Total Sales by Age Group')
ax.set_xlabel('Age Group')
ax.set_ylabel('Total Sales Amount')

plt.show()

# %% [markdown]
# #### From above graph we cn see that most of the buyers are from age group 26-35 years female

# %% [markdown]
# # State

# %%
sns.set(style='whitegrid', rc={'figure.figsize': (15, 5)})

orders_per_state = df['State'].value_counts().nlargest(10).reset_index()
orders_per_state.columns = ['State', 'Order_Count']

palette = sns.color_palette('Set2', n_colors=10)

ax = sns.barplot(
    x='State',
    y='Order_Count',
    data=orders_per_state,
    hue='State',         # fix warning by assigning hue
    palette=palette,
    dodge=False,
    legend=False
)
# Add values on top of each bar
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 10,  # slight padding above the bar
            f'{int(height)}', ha='center', va='bottom', fontsize=14)

ax.set_title('Total Number of Orders from Top 10 States')
ax.set_xlabel('State')
ax.set_ylabel('Number of Orders')

plt.xticks(rotation=0, ha='center')
plt.tight_layout()
plt.show()

# %%
# Set style and figure size
sns.set(style='whitegrid', rc={'figure.figsize': (15, 5)})

# Group by State and sum Amount, then get top 10 states by sales amount
sales_per_state = (
    df.groupby('State', as_index=False)['Amount']
      .sum()
      .sort_values(by='Amount', ascending=False)
      .head(10)
)

# Define color palette
palette = sns.color_palette('Set2', n_colors=10)

# Plot with hue='State' to avoid warning and legend=False to hide legend
ax = sns.barplot(
    x='State',
    y='Amount',
    data=sales_per_state,
    hue='State',
    palette=palette,
    dodge=False,
    legend=False
)

# Add values on top of each bar
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 10,  # slight padding above the bar
            f'{int(height)}', ha='center', va='bottom', fontsize=14)


ax.set_title('Total Sales Amount from Top 10 States')
ax.set_xlabel('State')
ax.set_ylabel('Total Sales Amount')

plt.xticks(rotation=0, ha='center')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### From above graph we can see that most of the sales and total sales/Amount are from Uttar Pradesh, Maharashtra, Karnataka.

# %% [markdown]
# # Maritial Status

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style='whitegrid', rc={'figure.figsize': (7, 5)})

# Define 2-color palette
palette = sns.color_palette('Set2', n_colors=2)

# Plot using hue to avoid warning
ax = sns.countplot(x='Marital_Status', hue='Marital_Status', data=df, palette=palette, legend=False)

# Add value labels
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5,
            f'{int(height)}', ha='center', va='bottom', fontsize=14)

plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.title('Distribution of Marital Status')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style='whitegrid', rc={'figure.figsize': (7, 5)})

# Optional: drop NaN values
df = df.dropna(subset=['Marital_Status'])

# Custom palette (optional)
palette = sns.color_palette('Set2', n_colors=2)

# Countplot with hue = Marital_Status
ax = sns.countplot(x='Marital_Status', hue='Marital_Status', data=df, palette=palette, legend=False)

# Add count labels
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5,
            f'{int(height)}', ha='center', va='bottom', fontsize=12)

plt.xlabel('Marital Status', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Distribution of Marital Status', fontsize=14)
plt.tight_layout()
plt.show()

# %%
# Group and sum Amount by Marital Status and Gender
Sales_age = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

# Set style and figure size
sns.set(style='whitegrid', rc={'figure.figsize': (7, 5)})

# Define color palette based on number of genders
palette = sns.color_palette('Set2', n_colors=df['Gender'].nunique())

# Plot barplot with hue for Gender
ax = sns.barplot(x='Marital_Status', y='Amount', hue='Gender', data=Sales_age, palette=palette)

# Add values on top of each bar
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 10,  # slight padding above the bar
            f'{int(height)}', ha='center', va='bottom', fontsize=14)

# Add title and labels
ax.set_title('Total Sales by Marital Status and Gender')
ax.set_xlabel('Marital Status')
ax.set_ylabel('Total Sales Amount')

# Show the plot (no label rotation)
plt.show()

# %% [markdown]
# #### From above graph we can see that most of the buyers are married women and have high purchasing

# %% [markdown]
# # Occupation

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set style and figure size
sns.set(style='whitegrid', rc={'figure.figsize': (20, 5)})

# Get number of unique occupations
num_occupations = df['Occupation'].nunique()

# Use a large enough color palette
palette = sns.color_palette('tab20', n_colors=num_occupations)


# Safe usage for Seaborn v0.14+
ax = sns.countplot(x='Occupation', hue='Occupation', data=df, palette=palette, legend=False)

# Add value labels on top
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5,
            f'{int(height)}', ha='center', va='bottom', fontsize=10)

# Style tweaks
plt.xlabel('Occupation', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Distribution of Occupation', fontsize=14)
plt.tight_layout()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Group and sum Amount by Occupation
Sales_Occupation = df.groupby('Occupation', as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

# Set style and figure size
sns.set(style='whitegrid', rc={'figure.figsize': (20, 5)})

# Define a color palette with enough colors
palette = sns.color_palette('husl', n_colors=Sales_Occupation['Occupation'].nunique())

# Plot barplot with hue set to Occupation (and hide the redundant legend)
ax = sns.barplot(
    x='Occupation',
    y='Amount',
    hue='Occupation',
    data=Sales_Occupation,
    palette=palette,
    legend=False  # No need to show a legend since Occupation is already on x-axis
)

# Add values on top of each bar
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 10,  # slight padding above the bar
            f'{int(height)}', ha='center', va='bottom', fontsize=14)


# Add title and labels
ax.set_title('Total Sales by Occupation')
ax.set_xlabel('Occupation')
ax.set_ylabel('Total Sales Amount')

# Show the plot
plt.show()

# %% [markdown]
# #### From above graph we can see that most of the buyers are from ITSector, Healthcare, Aviation

# %% [markdown]
# # Product

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import textwrap

def wrap_label(label, width=10):
    return '\n'.join(textwrap.wrap(label, width=width))

df['Product_Category'] = df['Product_Category'].apply(wrap_label)

sns.set(style='whitegrid', rc={'figure.figsize': (20, 6)})

num_cats = df['Product_Category'].nunique()
palette = sns.color_palette('Set2', n_colors=num_cats)

# Use hue and legend=False to avoid the deprecation warning
ax = sns.countplot(x='Product_Category', hue='Product_Category', data=df, palette=palette, legend=False)

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width()/2., height + 10,
            f'{int(height)}', ha='center', va='bottom', fontsize=14)

plt.xlabel('Product Category')
plt.ylabel('Count')
plt.title('Product Category Distribution')

plt.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Group and sum Amount by Product Category
Sales_Product = df.groupby('Product_Category', as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

# Optional: wrap long labels
Sales_Product['Product_Category'] = Sales_Product['Product_Category'].apply(lambda x: '\n'.join(x.split()))

# Set style and figure size
sns.set(style='whitegrid', rc={'figure.figsize': (22, 5)})

# Define a color palette
palette = sns.color_palette('husl', n_colors=Sales_Product['Product_Category'].nunique())

# Plot barplot (no hue needed)
ax = sns.barplot(
    x='Product_Category',
    y='Amount',
    hue='Product_Category',    
    data=Sales_Product,
    palette=palette,
    legend=False                
)


# Add values on top of each bar
for p in ax.patches:
    height = p.get_height()
    ax.text(
        p.get_x() + p.get_width() / 2.,
        height + 10,
        f'{int(height)}',
        ha='center',
        va='bottom',
        fontsize=14
    )

# Add title and labels
ax.set_title('Total Sales by Product Category', fontsize=18)
ax.set_xlabel('Product Category')
ax.set_ylabel('Total Sales Amount')

# Show the plot
plt.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# #### From above graph we can see that most of the products sold sre Food, Clothing & Apparel, Electronic Gadets.

# %%
# Top 10 most products sold
Sales_Orders = df.groupby('Product_ID', as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

# Set style and figure size
sns.set(style='whitegrid', rc={'figure.figsize': (20, 5)})

# Define a color palette based on number of unique products
palette = sns.color_palette('husl', n_colors=Sales_Orders['Product_ID'].nunique())

# Plot barplot with hue set to Product_ID to use palette, hide legend
ax = sns.barplot(
    x='Product_ID',
    y='Orders',
    hue='Product_ID',
    data=Sales_Orders,
    palette=palette,
    legend=False
)

# Add values on top of each bar
for p in ax.patches:
    height = p.get_height()
    ax.text(
        p.get_x() + p.get_width() / 2.,
        height + 10,  # padding above bar
        f'{int(height)}',
        ha='center',
        va='bottom',
        fontsize=14
    )

# Add title and labels
ax.set_title('Total Orders by Product')
ax.set_xlabel('Product ID')
ax.set_ylabel('Total Orders')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conclusion : From above Graphs we can see that most of the buyers are female, married and are from age group 26-35 years.The total sales is from Uttar Pradesh, Maharashtra, Karnataka most of the buyers are from ITSector, Healthcare, Aviation.
